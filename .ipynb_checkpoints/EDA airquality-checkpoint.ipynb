# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Load the CSV file
df = pd.read_csv("California_airquality.csv")

df
# Out:
#           Date Source   Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0       1/1/20    AQS  60010007    3                             8.6
# 1       1/2/20    AQS  60010007    3                             4.5
# 2       1/3/20    AQS  60010007    3                            14.2
# 3       1/4/20    AQS  60010007    3                            10.9
# 4       1/5/20    AQS  60010007    3                             7.8
# ...        ...    ...       ...  ...                             ...
# 30510  3/28/20    AQS  61131003    1                             1.0
# 30511   4/3/20    AQS  61131003    1                             1.0
# 30512  4/15/20    AQS  61131003    1                             6.5
# 30513  4/21/20    AQS  61131003    1                             7.2
# 30514  4/27/20    AQS  61131003    1                             5.5
#
#           UNITS  DAILY_AQI_VALUE             Site Name  DAILY_OBS_COUNT  \
# 0      ug/m3 LC               36             Livermore                1
# 1      ug/m3 LC               19             Livermore                1
# 2      ug/m3 LC               55             Livermore                1
# 3      ug/m3 LC               45             Livermore                1
# 4      ug/m3 LC               33             Livermore                1
# ...         ...              ...                   ...              ...
# 30510  ug/m3 LC                4  Woodland-Gibson Road                1
# 30511  ug/m3 LC                4  Woodland-Gibson Road                1
# 30512  ug/m3 LC               27  Woodland-Gibson Road                1
# 30513  ug/m3 LC               30  Woodland-Gibson Road                1
# 30514  ug/m3 LC               23  Woodland-Gibson Road                1
#
#        PERCENT_COMPLETE  AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  \
# 0                   100               88101  PM2.5 - Local Conditions
# 1                   100               88101  PM2.5 - Local Conditions
# 2                   100               88101  PM2.5 - Local Conditions
# 3                   100               88101  PM2.5 - Local Conditions
# 4                   100               88101  PM2.5 - Local Conditions
# ...                 ...                 ...                       ...
# 30510               100               88101  PM2.5 - Local Conditions
# 30511               100               88101  PM2.5 - Local Conditions
# 30512               100               88101  PM2.5 - Local Conditions
# 30513               100               88101  PM2.5 - Local Conditions
# 30514               100               88101  PM2.5 - Local Conditions
#
#        CBSA_CODE                                CBSA_NAME  STATE_CODE  \
# 0        41860.0        San Francisco-Oakland-Hayward, CA           6
# 1        41860.0        San Francisco-Oakland-Hayward, CA           6
# 2        41860.0        San Francisco-Oakland-Hayward, CA           6
# 3        41860.0        San Francisco-Oakland-Hayward, CA           6
# 4        41860.0        San Francisco-Oakland-Hayward, CA           6
# ...          ...                                      ...         ...
# 30510    40900.0  Sacramento--Roseville--Arden-Arcade, CA           6
# 30511    40900.0  Sacramento--Roseville--Arden-Arcade, CA           6
# 30512    40900.0  Sacramento--Roseville--Arden-Arcade, CA           6
# 30513    40900.0  Sacramento--Roseville--Arden-Arcade, CA           6
# 30514    40900.0  Sacramento--Roseville--Arden-Arcade, CA           6
#
#             STATE  COUNTY_CODE   COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0      California            1  Alameda      37.687526     -121.784217
# 1      California            1  Alameda      37.687526     -121.784217
# 2      California            1  Alameda      37.687526     -121.784217
# 3      California            1  Alameda      37.687526     -121.784217
# 4      California            1  Alameda      37.687526     -121.784217
# ...           ...          ...      ...            ...             ...
# 30510  California          113     Yolo      38.661210     -121.732690
# 30511  California          113     Yolo      38.661210     -121.732690
# 30512  California          113     Yolo      38.661210     -121.732690
# 30513  California          113     Yolo      38.661210     -121.732690
# 30514  California          113     Yolo      38.661210     -121.732690
#
# [30515 rows x 20 columns]

# %%
df.head(5)
# Out:
#      Date Source   Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  1/1/20    AQS  60010007    3                             8.6  ug/m3 LC
# 1  1/2/20    AQS  60010007    3                             4.5  ug/m3 LC
# 2  1/3/20    AQS  60010007    3                            14.2  ug/m3 LC
# 3  1/4/20    AQS  60010007    3                            10.9  ug/m3 LC
# 4  1/5/20    AQS  60010007    3                             7.8  ug/m3 LC
#
#    DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               36  Livermore                1               100
# 1               19  Livermore                1               100
# 2               55  Livermore                1               100
# 3               45  Livermore                1               100
# 4               33  Livermore                1               100
#
#    AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               88101  PM2.5 - Local Conditions    41860.0
# 1               88101  PM2.5 - Local Conditions    41860.0
# 2               88101  PM2.5 - Local Conditions    41860.0
# 3               88101  PM2.5 - Local Conditions    41860.0
# 4               88101  PM2.5 - Local Conditions    41860.0
#
#                            CBSA_NAME  STATE_CODE       STATE  COUNTY_CODE  \
# 0  San Francisco-Oakland-Hayward, CA           6  California            1
# 1  San Francisco-Oakland-Hayward, CA           6  California            1
# 2  San Francisco-Oakland-Hayward, CA           6  California            1
# 3  San Francisco-Oakland-Hayward, CA           6  California            1
# 4  San Francisco-Oakland-Hayward, CA           6  California            1
#
#     COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0  Alameda      37.687526     -121.784217
# 1  Alameda      37.687526     -121.784217
# 2  Alameda      37.687526     -121.784217
# 3  Alameda      37.687526     -121.784217
# 4  Alameda      37.687526     -121.784217

# %%
print(df.columns)
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
df.columns = (df.columns
                .str.strip()
                .str.lower()
                .str.replace(' ', '_')
                .str.replace(r'[^\w]', '', regex=True))

# %%
for col in ['daily_mean_pm25_concentration','daily_aqi_value','daily_obs_count',
            'percent_complete','site_latitude','site_longitude']:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df['site_name'] = df['site_name'].fillna('Unknown')
df.dropna(subset=['daily_mean_pm25_concentration','daily_aqi_value'], inplace=True)

# %%
# 2) PM2.5 vs AQI scatter
plt.figure()
plt.scatter(df.daily_mean_pm25_concentration, df.daily_aqi_value, s=5)
plt.title("PM2.5 vs AQI")
plt.xlabel("Daily Mean PM2.5 (µg/m³)")
plt.ylabel("Daily AQI Value")
plt.tight_layout()
plt.show()

# %%
# 2) Parse the date
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%y', errors='coerce')
# check conversion
print(df['date'].dtype)   # should show datetime64[ns]

# 3) Drop any rows where date failed to parse
df = df.dropna(subset=['date'])

# 4) Extract month
df['month'] = df['date'].dt.month

# 5) Monthly PM2.5 boxplots
data_by_month = [
    df.loc[df['month'] == m, 'daily_mean_pm25_concentration']
      .dropna()
    for m in range(1, 13)
]

plt.figure(figsize=(8,4))
plt.boxplot(data_by_month, labels=range(1,13))
plt.title("Monthly PM2.5 Distribution")
plt.xlabel("Month")
plt.ylabel("Daily Mean PM2.5 (µg/m³)")
plt.tight_layout()
plt.show()
# Out:
# datetime64[ns]
# /var/folders/ch/501q6vqd6s10pmgmd7ytk7ph0000gp/T/ipykernel_71094/188065178.py:20: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_by_month, labels=range(1,13))

# %%
 # 4) Correlation heatmap
num = ['daily_mean_pm25_concentration','daily_aqi_value','daily_obs_count',
       'percent_complete','site_latitude','site_longitude']
corr = df[num].corr()
plt.figure()
plt.imshow(corr, interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(num)), num, rotation=45, ha='right')
plt.yticks(range(len(num)), num)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
# 5) Monthly trend for top-3 counties
top3 = (
    df['county']
      .value_counts()
      .nlargest(3)
      .index
      .tolist()
)

plt.figure(figsize=(10, 5))

for county in top3:
    # filter, set datetime index, select PM2.5, resample, and average
    ts = (
        df.loc[df['county'] == county]
          .set_index('date')['daily_mean_pm25_concentration']
          # future-proof monthly frequency: use 'ME' (month end) or 'MS' (month start)
          .resample('ME')
          .mean()
    )
    plt.plot(ts.index, ts.values, marker='o', label=county)

plt.title("Monthly Avg PM2.5 for Top 3 Counties")
plt.xlabel("Date")
plt.ylabel("Avg PM2.5 (µg/m³)")
plt.legend(title="County")
plt.tight_layout()
plt.show()

# %%
# 6) AQI distribution + PM2.5 > “unhealthy” days
plt.figure(figsize=(6,4))
plt.hist(df['daily_aqi_value'], bins=25)
plt.title("Distribution of Daily AQI Values")
plt.xlabel("AQI")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
# mark days above AQI 100
unhealthy = df[df['daily_aqi_value'] > 100].shape[0]
total_days = df.shape[0]
print(f"Days with AQI>100: {unhealthy} ({unhealthy/total_days:.1%} of all records)")
# Out:
# Days with AQI>100: 698 (2.3% of all records)

# %%
# 7) PM2.5 vs obs count (data completeness check)
plt.figure(figsize=(6,4))
plt.scatter(df['daily_obs_count'], df['daily_mean_pm25_concentration'], s=3)
plt.title("Observations Count vs PM2.5")
plt.xlabel("Daily Obs Count")
plt.ylabel("Daily Mean PM2.5")
plt.tight_layout()
plt.show()
